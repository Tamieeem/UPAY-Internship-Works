# %%
class FunA:
  change = 15

  def __init__(self,name,id):
    self.name = name
    self.id = id

  def detail(self):
    print('G')

  def goz(self):
    print('I am here')



tamim = FunA('tamim',2334111)

print(tamim.change)
print(FunA.change)
# Out:
# 15
# 15

# %%
class Person:
  def __init__(self, name, age=25):
    self.name = name
    self.age = age


p1 = Person("Tobias", 25)
print(p1.age)

p1.age = 26
print(p1.age)
# Out:
# 25
# 26

# %%
class Person:
  def __init__(self, name):
    self.name = name



p1 = Person("Tobias")

p1.age = 25
p1.city = "Oslo"

print(p1.name)
print(p1.age)
print(p1.city)
# Out:
# Tobias
# 25
# Oslo

# %%
class Person:
  def __init__(self, name, age=25, city='bd'):
    self.name = name

p1 = Person("Tobias")
# Out:
# Tobias

# %%
class Person:
  def __init__(self, name, age):
    self.name = name
    self.age = age

  def __str__(self):
    return f"{self.name} ({self.age})"

p1 = Person("Tobias", 36)
print(p1)
# Out:
# Tobias (36)

# %%
class Playlist:
  def __init__(self, name):
    self.name = name
    self.songs = []

  def add_song(self, song):
    self.songs.append(song)
    print(f"Added: {song}")

  def remove_song(self, song):
    if song in self.songs:
      self.songs.remove(song)
      print(f"Removed: {song}")

  def show_songs(self):
    print(f"Playlist '{self.name}':")
    for song in self.songs:
      print(f"- {song}")

my_playlist = Playlist("Favorites")
my_playlist.add_song("Bohemian Rhapsody")
my_playlist.add_song("Stairway to Heaven")
my_playlist.show_songs()
# Out:
# Added: Bohemian Rhapsody
# Added: Stairway to Heaven
# Playlist 'Favorites':
# - Bohemian Rhapsody
# - Stairway to Heaven

# %%
class Person:
  def __init__(self, fname, lname):
    self.firstname = fname
    self.lastname = lname

  def printname(self):
    print(self.firstname, self.lastname)

class Student(Person):
  def __init__(self, first, last, age, id):
    #super().__init__(first, last)
    Person.__init__(self,first, last)
    self.age = age
    self.id = id
    self.year = 2026

  def printD(self):
    print(f'{self.firstname}\n{self.lastname}\n{self.age}\n{self.id}\n{self.year}')

x = Student("Gandu", "Tamim", 25, 2414)
x.printD()
# Out:
# Gandu
# Tamim
# 25
# 2414
# 2026

# %%
class Car:
  def __init__(self, brand, model):
    self.brand = brand
    self.model = model

  def move(self):
    print("Drive!")

class Boat:
  def __init__(self, brand, model):
    self.brand = brand
    self.model = model

  def move(self):
    print("Sail!")

class Plane:
  def __init__(self, brand, model):
    self.brand = brand
    self.model = model

  def move(self):
    print("Fly!")

car1 = Car("Ford", "Mustang")       #Create a Car object
boat1 = Boat("Ibiza", "Touring 20") #Create a Boat object
plane1 = Plane("Boeing", "747")     #Create a Plane object

for x in (car1, boat1, plane1):
  x.move()
# Out:
# Drive!
# Sail!
# Fly!

# %%
class Vehicle:
  def __init__(self, brand, model):
    self.brand = brand
    self.model = model

  def move(self):
    print("Move!")

class Car(Vehicle):
  pass

class Boat(Vehicle):
  def move(self):
    print("Sail!")

class Plane(Vehicle):
  def move(self):
    print("Fly!")

car1 = Car("Ford", "Mustang")
boat1 = Boat("Ibiza", "Touring 20")
plane1 = Plane("Boeing", "747")

for x in (car1, boat1, plane1):
  x.move()
# Out:
# Move!
# Sail!
# Fly!

# %%
class Person:
  def __init__(self, name, age):
    self.name = name
    self.__age = age

  def get_age(self):
    return f"{self.__age}"

p1 = Person("Emil", 25)
print(p1.name)
print(p1.get_age())
# Out:
# Emil
# 25

# %%
class Car:
  class Engine:
      def __init__(self):
        self.running = False

      def start(self):
        self.running = True
        print("Engine Started")

      def stop(self):
        self.running = False
        print("Engine stopped")


  def __init__(self, brand, model):
    self.brand = brand
    self.model = model
    self.engine = self.Engine()




  def drive(self):
    if self.engine.running:
      print("Driving the toyota Corolla")
    else:
      print("Start the engine first!")

car = Car("Toyota", "Corolla")
car.drive()
car.engine.start()
car.drive()
# Out:
# Start the engine first!
# Engine Started
# Driving the toyota Corolla

# %%
class Computer:
  class CPU:
    def __init__(self):
      pass

    def process(self):
      print('Processing Data')

  class RAM:
    def __init(__self):
      pass

    def store(self):
      print('Storing Data...')


  def __init__(self):
    self.cpu = self.CPU()
    self.ram = self.RAM()


computer = Computer()
computer.cpu.process()
computer.ram.store()
# Out:
# Processing Data
# Storing Data...

# %%
class BankAccount:
    def __init__(self, balance):
      self.__balance = balance
    def deposit(self, depo):
      self.__balance += depo
    def withdraw(self, wdraw):
      self.__balance =- wdraw



account = BankAccount(1000)
account.deposit(500)
account.withdraw(300)

print(account.get_balance())

# %%
class Gixxer:
  def __init__(self):
    self.lis = []

  def monotone(self, *kwargs):
    for val in kwargs:
      self.lis.append(val)

  def printDetails(self):
    for items in self.lis:
      print(items)





g1 = Gixxer()
g1.monotone("155cc")
g1.monotone(8000, 6000) #maxpower, maxtorque
g1.monotone("Carburetor", 125, 40) #fuelsystem, top, mileage
g1.printDetails()
# Out:
# 155cc
# 8000
# 6000
# Carburetor
# 125
# 40
